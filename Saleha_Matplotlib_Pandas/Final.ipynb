# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# %matplotlib inline

# %%
df=pd.read_csv("Vic_New.csv")

# %%
df.isnull().sum()
# Out:
# streetNumber                 0
# streetName                   0
# streetType                  11
# suburb                       0
# postcode                     9
# state                        9
# geoLocation                  9
# propertyType                 0
# bedrooms                     0
# bathrooms                    9
# carspaces                    9
# result                       0
# agent                        0
# id                           0
# agencyId                     0
# agencyName                   9
# agencyProfilePageUrl         9
# propertyDetailsUrl           0
# price                        0
# unitNumber                 449
# area                         0
# second_ID                    0
# canonicalUrl                 0
# areaSize                     0
# photos                       0
# LGA                          9
# lga_desc                     9
# lga_ID                       9
# Suburb                      22
# Postcode                    22
# Lat                         22
# Lng                         22
# Domain_id                   22
# medianSoldPrice             64
# numberSold                  39
# highestSoldPrice            39
# lowestSoldPrice             39
# medianSaleListingPrice      59
# numberSaleListing           35
# highestSaleListingPrice     35
# lowestSaleListingPrice      35
# auctionNumberAuctioned      46
# auctionNumberSold           46
# auctionNumberWithdrawn     628
# daysOnMarket               108
# medianRentListingPrice      68
# numberRentListing           44
# highestRentListingPrice     58
# lowestRentListingPrice      44
# dtype: int64

# %%
df.head()
# Out:
#   streetNumber streetName streetType        suburb  postcode state  \
# 0           11       Park         St    Abbotsford    3067.0   Vic
# 1           75     Halsey         Rd  Airport West    3042.0   Vic
# 2           18  Highridge         Cr  Airport West    3042.0   Vic
# 3           52   McIntosh         St  Airport West    3042.0   Vic
# 4           10   Delamare         Dr     Albanvale    3021.0   Vic
#
#                                          geoLocation propertyType  bedrooms  \
# 0  {'latitude': -37.8091018, 'longitude': 144.993...        House         4
# 1  {'latitude': -37.7190478, 'longitude': 144.885...        House         3
# 2  {'latitude': -37.7274118, 'longitude': 144.882...        House         3
# 3  {'latitude': -37.7209776, 'longitude': 144.886...    Townhouse         3
# 4  {'latitude': -37.742586, 'longitude': 144.7658...        House         4
#
#    bathrooms  ...  highestSaleListingPrice lowestSaleListingPrice  \
# 0        1.0  ...                2200000.0               360000.0
# 1        2.0  ...                1300000.0               470000.0
# 2        1.0  ...                1300000.0               470000.0
# 3        1.0  ...                1300000.0               470000.0
# 4        2.0  ...                1192000.0               365000.0
#
#   auctionNumberAuctioned  auctionNumberSold  auctionNumberWithdrawn  \
# 0                   23.0               13.0                     NaN
# 1                   32.0               17.0                     NaN
# 2                   32.0               17.0                     NaN
# 3                   32.0               17.0                     NaN
# 4                    5.0                4.0                     NaN
#
#   daysOnMarket medianRentListingPrice numberRentListing  \
# 0         51.0                  625.0              63.0
# 1         39.0                  490.0              86.0
# 2         39.0                  490.0              86.0
# 3         39.0                  490.0              86.0
# 4         66.0                  350.0              16.0
#
#    highestRentListingPrice lowestRentListingPrice
# 0                   1300.0                  325.0
# 1                    660.0                  320.0
# 2                    660.0                  320.0
# 3                    660.0                  320.0
# 4                    490.0                  300.0
#
# [5 rows x 49 columns]

# %%
df.drop_duplicates()
df
# Out:
#     streetNumber streetName streetType        suburb  postcode state  \
# 0             11       Park         St    Abbotsford    3067.0   Vic
# 1             75     Halsey         Rd  Airport West    3042.0   Vic
# 2             18  Highridge         Cr  Airport West    3042.0   Vic
# 3             52   McIntosh         St  Airport West    3042.0   Vic
# 4             10   Delamare         Dr     Albanvale    3021.0   Vic
# ..           ...        ...        ...           ...       ...   ...
# 623          202    Osborne         St  Williamstown    3016.0   Vic
# 624            9    Railway         Pl  Williamstown    3016.0   Vic
# 625           16  Chromatic         Rd       Wollert    3750.0   Vic
# 626           36   Varanasi         Dr       Wollert    3750.0   Vic
# 627           87   Hamilton         St    Yarraville    3013.0   Vic
#
#                                            geoLocation propertyType  bedrooms  \
# 0    {'latitude': -37.8091018, 'longitude': 144.993...        House         4
# 1    {'latitude': -37.7190478, 'longitude': 144.885...        House         3
# 2    {'latitude': -37.7274118, 'longitude': 144.882...        House         3
# 3    {'latitude': -37.7209776, 'longitude': 144.886...    Townhouse         3
# 4    {'latitude': -37.742586, 'longitude': 144.7658...        House         4
# ..                                                 ...          ...       ...
# 623  {'latitude': -37.8641318, 'longitude': 144.891...        House         4
# 624  {'latitude': -37.8665184, 'longitude': 144.902...        House         4
# 625  {'latitude': -37.6041712, 'longitude': 145.004...        House         4
# 626  {'latitude': -37.5976217, 'longitude': 144.986...        House         4
# 627  {'latitude': -37.811757, 'longitude': 144.886935}        House         3
#
#      bathrooms  ...  highestSaleListingPrice lowestSaleListingPrice  \
# 0          1.0  ...                2200000.0               360000.0
# 1          2.0  ...                1300000.0               470000.0
# 2          1.0  ...                1300000.0               470000.0
# 3          1.0  ...                1300000.0               470000.0
# 4          2.0  ...                1192000.0               365000.0
# ..         ...  ...                      ...                    ...
# 623        2.0  ...                5000000.0               630000.0
# 624        2.0  ...                5000000.0               630000.0
# 625        2.0  ...                1450000.0               200000.0
# 626        2.0  ...                1450000.0               200000.0
# 627        1.0  ...                2800000.0               400000.0
#
#     auctionNumberAuctioned  auctionNumberSold  auctionNumberWithdrawn  \
# 0                     23.0               13.0                     NaN
# 1                     32.0               17.0                     NaN
# 2                     32.0               17.0                     NaN
# 3                     32.0               17.0                     NaN
# 4                      5.0                4.0                     NaN
# ..                     ...                ...                     ...
# 623                   45.0               28.0                     NaN
# 624                   45.0               28.0                     NaN
# 625                   47.0               28.0                     NaN
# 626                   47.0               28.0                     NaN
# 627                   56.0               37.0                     NaN
#
#     daysOnMarket medianRentListingPrice numberRentListing  \
# 0           51.0                  625.0              63.0
# 1           39.0                  490.0              86.0
# 2           39.0                  490.0              86.0
# 3           39.0                  490.0              86.0
# 4           66.0                  350.0              16.0
# ..           ...                    ...               ...
# 623         42.0                  670.0              91.0
# 624         42.0                  670.0              91.0
# 625         97.0                  420.0             168.0
# 626         97.0                  420.0             168.0
# 627         50.0                  520.0             193.0
#
#      highestRentListingPrice lowestRentListingPrice
# 0                     1300.0                  325.0
# 1                      660.0                  320.0
# 2                      660.0                  320.0
# 3                      660.0                  320.0
# 4                      490.0                  300.0
# ..                       ...                    ...
# 623                   1675.0                  315.0
# 624                   1675.0                  315.0
# 625                   2511.0                  320.0
# 626                   2511.0                  320.0
# 627                    950.0                  150.0
#
# [628 rows x 49 columns]

# %%
drop_all_na = df.dropna(how = 'all')
drop_all_na
# Out:
#     streetNumber streetName streetType        suburb  postcode state  \
# 0             11       Park         St    Abbotsford    3067.0   Vic
# 1             75     Halsey         Rd  Airport West    3042.0   Vic
# 2             18  Highridge         Cr  Airport West    3042.0   Vic
# 3             52   McIntosh         St  Airport West    3042.0   Vic
# 4             10   Delamare         Dr     Albanvale    3021.0   Vic
# ..           ...        ...        ...           ...       ...   ...
# 623          202    Osborne         St  Williamstown    3016.0   Vic
# 624            9    Railway         Pl  Williamstown    3016.0   Vic
# 625           16  Chromatic         Rd       Wollert    3750.0   Vic
# 626           36   Varanasi         Dr       Wollert    3750.0   Vic
# 627           87   Hamilton         St    Yarraville    3013.0   Vic
#
#                                            geoLocation propertyType  bedrooms  \
# 0    {'latitude': -37.8091018, 'longitude': 144.993...        House         4
# 1    {'latitude': -37.7190478, 'longitude': 144.885...        House         3
# 2    {'latitude': -37.7274118, 'longitude': 144.882...        House         3
# 3    {'latitude': -37.7209776, 'longitude': 144.886...    Townhouse         3
# 4    {'latitude': -37.742586, 'longitude': 144.7658...        House         4
# ..                                                 ...          ...       ...
# 623  {'latitude': -37.8641318, 'longitude': 144.891...        House         4
# 624  {'latitude': -37.8665184, 'longitude': 144.902...        House         4
# 625  {'latitude': -37.6041712, 'longitude': 145.004...        House         4
# 626  {'latitude': -37.5976217, 'longitude': 144.986...        House         4
# 627  {'latitude': -37.811757, 'longitude': 144.886935}        House         3
#
#      bathrooms  ...  highestSaleListingPrice lowestSaleListingPrice  \
# 0          1.0  ...                2200000.0               360000.0
# 1          2.0  ...                1300000.0               470000.0
# 2          1.0  ...                1300000.0               470000.0
# 3          1.0  ...                1300000.0               470000.0
# 4          2.0  ...                1192000.0               365000.0
# ..         ...  ...                      ...                    ...
# 623        2.0  ...                5000000.0               630000.0
# 624        2.0  ...                5000000.0               630000.0
# 625        2.0  ...                1450000.0               200000.0
# 626        2.0  ...                1450000.0               200000.0
# 627        1.0  ...                2800000.0               400000.0
#
#     auctionNumberAuctioned  auctionNumberSold  auctionNumberWithdrawn  \
# 0                     23.0               13.0                     NaN
# 1                     32.0               17.0                     NaN
# 2                     32.0               17.0                     NaN
# 3                     32.0               17.0                     NaN
# 4                      5.0                4.0                     NaN
# ..                     ...                ...                     ...
# 623                   45.0               28.0                     NaN
# 624                   45.0               28.0                     NaN
# 625                   47.0               28.0                     NaN
# 626                   47.0               28.0                     NaN
# 627                   56.0               37.0                     NaN
#
#     daysOnMarket medianRentListingPrice numberRentListing  \
# 0           51.0                  625.0              63.0
# 1           39.0                  490.0              86.0
# 2           39.0                  490.0              86.0
# 3           39.0                  490.0              86.0
# 4           66.0                  350.0              16.0
# ..           ...                    ...               ...
# 623         42.0                  670.0              91.0
# 624         42.0                  670.0              91.0
# 625         97.0                  420.0             168.0
# 626         97.0                  420.0             168.0
# 627         50.0                  520.0             193.0
#
#      highestRentListingPrice lowestRentListingPrice
# 0                     1300.0                  325.0
# 1                      660.0                  320.0
# 2                      660.0                  320.0
# 3                      660.0                  320.0
# 4                      490.0                  300.0
# ..                       ...                    ...
# 623                   1675.0                  315.0
# 624                   1675.0                  315.0
# 625                   2511.0                  320.0
# 626                   2511.0                  320.0
# 627                    950.0                  150.0
#
# [628 rows x 49 columns]

# %%
drop_all_na = df.dropna(how = 'any')
drop_all_na
# Out:
# Empty DataFrame
# Columns: [streetNumber, streetName, streetType, suburb, postcode, state, geoLocation, propertyType, bedrooms, bathrooms, carspaces, result, agent, id, agencyId, agencyName, agencyProfilePageUrl, propertyDetailsUrl, price, unitNumber, area, second_ID, canonicalUrl, areaSize, photos, LGA, lga_desc, lga_ID, Suburb, Postcode, Lat, Lng, Domain_id, medianSoldPrice, numberSold, highestSoldPrice, lowestSoldPrice, medianSaleListingPrice, numberSaleListing, highestSaleListingPrice, lowestSaleListingPrice, auctionNumberAuctioned, auctionNumberSold, auctionNumberWithdrawn, daysOnMarket, medianRentListingPrice, numberRentListing, highestRentListingPrice, lowestRentListingPrice]
# Index: []
#
# [0 rows x 49 columns]

# %%
plt.figure(figsize=(15,10))
sns.barplot(data=df,x='bedrooms',y='price',palette='Set2')
plt.xlabel("Number of Bedroom", size=20)
plt.ylabel("price", size=20)
plt.title("Total Price of Houses in Melbourne by Bedroom", size=25)
plt.tight_layout()

# %%
plt.figure(figsize=(15,10))
sns.barplot(data=df,x='bathrooms',y='price',palette='Set2')
plt.xlabel("Number of Bathroom", size=20)
plt.ylabel("price", size=20)
plt.title("Total Price of Houses in Melbourne by Bathroom", size=25)
plt.tight_layout()

# %%
import matplotlib.image as mpimg 
map_img = mpimg.imread('../Images/smart dolphin.jpg') 

 


plt.figure(figsize=(15,10))
hmax=sns.barplot(data=df,x='carspaces',y='price',palette='Set2',zorder = 2)
hmax.imshow(map_img,
          aspect = hmax.get_aspect(),
          extent = hmax.get_xlim() + hmax.get_ylim(),
          zorder = 1,alpha = 0.5)
plt.xlabel("Number of Carport", size=20)
plt.ylabel("price", size=20)
plt.title("Total Price of Houses in Melbourne by Carport", size=25)
plt.tight_layout()
plt.show()

# %%
# plotting a heat map for all numeric variables
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),cmap = 'coolwarm',linewidth = 1,annot= True, annot_kws={"size": 9})
plt.title('HEAT MAP', fontsize=15)
plt.show()

# %%
df.hist(bins=50, figsize=(20,15))
plt.savefig("attribute_histogram_plots")
plt.show()

# %%
def plot_property_for_one(df, feature, value, ax):
    sns.scatterplot(x='Lng', y='Lat', data=df, alpha=0.5, color='white', ax=ax)
    ax.set_facecolor('0.6')
    ax.grid(False)
    color = sns.color_palette(n_colors=1)[0]
    sns.scatterplot(x='Lng', y='Lat', data=df.loc[df[feature] == value, :],
                    color=color, alpha=0.5, ax=ax)
    ax.set_title(value)
df
# Out:
#     streetNumber streetName streetType        suburb  postcode state  \
# 0             11       Park         St    Abbotsford    3067.0   Vic
# 1             75     Halsey         Rd  Airport West    3042.0   Vic
# 2             18  Highridge         Cr  Airport West    3042.0   Vic
# 3             52   McIntosh         St  Airport West    3042.0   Vic
# 4             10   Delamare         Dr     Albanvale    3021.0   Vic
# ..           ...        ...        ...           ...       ...   ...
# 623          202    Osborne         St  Williamstown    3016.0   Vic
# 624            9    Railway         Pl  Williamstown    3016.0   Vic
# 625           16  Chromatic         Rd       Wollert    3750.0   Vic
# 626           36   Varanasi         Dr       Wollert    3750.0   Vic
# 627           87   Hamilton         St    Yarraville    3013.0   Vic
#
#                                            geoLocation propertyType  bedrooms  \
# 0    {'latitude': -37.8091018, 'longitude': 144.993...        House         4
# 1    {'latitude': -37.7190478, 'longitude': 144.885...        House         3
# 2    {'latitude': -37.7274118, 'longitude': 144.882...        House         3
# 3    {'latitude': -37.7209776, 'longitude': 144.886...    Townhouse         3
# 4    {'latitude': -37.742586, 'longitude': 144.7658...        House         4
# ..                                                 ...          ...       ...
# 623  {'latitude': -37.8641318, 'longitude': 144.891...        House         4
# 624  {'latitude': -37.8665184, 'longitude': 144.902...        House         4
# 625  {'latitude': -37.6041712, 'longitude': 145.004...        House         4
# 626  {'latitude': -37.5976217, 'longitude': 144.986...        House         4
# 627  {'latitude': -37.811757, 'longitude': 144.886935}        House         3
#
#      bathrooms  ...  highestSaleListingPrice lowestSaleListingPrice  \
# 0          1.0  ...                2200000.0               360000.0
# 1          2.0  ...                1300000.0               470000.0
# 2          1.0  ...                1300000.0               470000.0
# 3          1.0  ...                1300000.0               470000.0
# 4          2.0  ...                1192000.0               365000.0
# ..         ...  ...                      ...                    ...
# 623        2.0  ...                5000000.0               630000.0
# 624        2.0  ...                5000000.0               630000.0
# 625        2.0  ...                1450000.0               200000.0
# 626        2.0  ...                1450000.0               200000.0
# 627        1.0  ...                2800000.0               400000.0
#
#     auctionNumberAuctioned  auctionNumberSold  auctionNumberWithdrawn  \
# 0                     23.0               13.0                     NaN
# 1                     32.0               17.0                     NaN
# 2                     32.0               17.0                     NaN
# 3                     32.0               17.0                     NaN
# 4                      5.0                4.0                     NaN
# ..                     ...                ...                     ...
# 623                   45.0               28.0                     NaN
# 624                   45.0               28.0                     NaN
# 625                   47.0               28.0                     NaN
# 626                   47.0               28.0                     NaN
# 627                   56.0               37.0                     NaN
#
#     daysOnMarket medianRentListingPrice numberRentListing  \
# 0           51.0                  625.0              63.0
# 1           39.0                  490.0              86.0
# 2           39.0                  490.0              86.0
# 3           39.0                  490.0              86.0
# 4           66.0                  350.0              16.0
# ..           ...                    ...               ...
# 623         42.0                  670.0              91.0
# 624         42.0                  670.0              91.0
# 625         97.0                  420.0             168.0
# 626         97.0                  420.0             168.0
# 627         50.0                  520.0             193.0
#
#      highestRentListingPrice lowestRentListingPrice
# 0                     1300.0                  325.0
# 1                      660.0                  320.0
# 2                      660.0                  320.0
# 3                      660.0                  320.0
# 4                      490.0                  300.0
# ..                       ...                    ...
# 623                   1675.0                  315.0
# 624                   1675.0                  315.0
# 625                   2511.0                  320.0
# 626                   2511.0                  320.0
# 627                    950.0                  150.0
#
# [628 rows x 49 columns]

# %%
# fig, axes = plt.subplots(3, 2, sharey=True, sharex=True)
df
highestSaleListingPrice = df.sort_values(by=["highestSaleListingPrice"],ascending=False)
# plot_property_for_one(highestSaleListingPrice[["suburb","highestSaleListingPrice"]].drop_duplicates(), 'toparea', axes[0][0])
# ax.set_facecolor('0.6')
# ax.grid(False)
color = sns.color_palette(n_colors=1)[0]
plt.xticks(rotation=45, ha='right')
dd=highestSaleListingPrice[["Lat","Lng","highestSaleListingPrice"]].drop_duplicates()
dd=dd.dropna()
print(dd)
sns.scatterplot(x=dd['Lat'], y=dd['Lng'], data=dd["highestSaleListingPrice"],
                    c=dd["highestSaleListingPrice"], alpha=0.5)
# ax.set_title(value)
# fig = plt.gcf()
# # fig.set_size_inches(16, 12)
# fig.suptitle('Phow()
highestSaleListingPrice[["suburb","highestSaleListingPrice"]].drop_duplicates()
# Out:
#            Lat         Lng  highestSaleListingPrice
# 301 -37.822211  145.032802               38000000.0
# 583 -37.843240  145.019024               33300000.0
# 244 -38.457454  144.972198               28429000.0
# 552 -37.542473  144.719238               26250000.0
# 139 -37.871263  145.019024               21000000.0
# ..         ...         ...                      ...
# 276 -37.704421  144.878623                 850000.0
# 365 -37.815207  144.963937                 789000.0
# 200 -38.115525  145.869060                 775000.0
# 356 -37.853515  145.035557                 669000.0
# 81  -38.176358  144.384984                 649000.0
#
# [170 rows x 3 columns]
#               suburb  highestSaleListingPrice
# 301         Hawthorn               38000000.0
# 583           Toorak               33300000.0
# 244         Flinders               28429000.0
# 552          Sunbury               26250000.0
# 139  Caulfield North               21000000.0
# ..               ...                      ...
# 539         St Kilda                      NaN
# 548    St Kilda West                      NaN
# 551       Strathmore                      NaN
# 564     Taylors Hill                      NaN
# 613         Werribee                      NaN
#
# [255 rows x 2 columns]
