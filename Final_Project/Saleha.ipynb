# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e2f9dbfc6569> in <module>
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
#       5 from pandas.plotting import scatter_matrix
#
# ~\anaconda3\lib\site-packages\numpy\__init__.py in <module>
#     142     from . import _distributor_init
#     143
# --> 144     from . import core
#     145     from .core import *
#     146     from . import compat
#
# ~\anaconda3\lib\site-packages\numpy\core\__init__.py in <module>
#      71 from . import numerictypes as nt
#      72 multiarray.set_typeDict(nt.sctypeDict)
# ---> 73 from . import numeric
#      74 from .numeric import *
#      75 from . import fromnumeric
#
# ~\anaconda3\lib\site-packages\numpy\core\numeric.py in <module>
#      21 from . import overrides
# ...

# %%
df=pd.read_csv("Vic_New.csv")

# %%
from sqlalchemy import create_engine
import pandas as pd

# for the username and password i have created a pgAdmin user acount named SQL_challange
engine = create_engine('postgresql://SQL_challange:SQL_challange@localhost:5432/EmployeeSQL')
connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-c9bdfd91dbdc> in <module>
#       1 from sqlalchemy import create_engine
# ----> 2 import pandas as pd
#       3
#       4 # for the username and password i have created a pgAdmin user acount named SQL_challange
#       5 engine = create_engine('postgresql://SQL_challange:SQL_challange@localhost:5432/EmployeeSQL')
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in <module>
#      14
#      15 if missing_dependencies:
# ---> 16     raise ImportError(
#      17         "Unable to import required dependencies:\n" + "\n".join(missing_dependencies)
#      18     )
#
# ImportError: Unable to import required dependencies:
# numpy: cannot import name 'asanyarray' from 'numpy.core.multiarray' (C:\Users\hatim\anaconda3\lib\site-packages\numpy\core\multiarray.py)

# %%
df.isnull().sum()
# Out:
# streetNumber            3317
# streetName              3317
# streetType              3328
# suburb                  3317
# postcode                3326
# state                   3326
# geoLocation             3326
# Lat                     3326
# Unnamed: 8              3326
# Lng                     3326
# propertyType            3317
# bedrooms                3317
# bathrooms               3326
# carspaces               3326
# result                  3317
# agent                   3317
# id                      3317
# agencyId                3317
# agencyName              3326
# agencyProfilePageUrl    3326
# propertyDetailsUrl      3317
# price                   3317
# unitNumber              3766
# second_ID               3317
# canonicalUrl            3317
# areaSize                3317
# photos                  3317
# LGA                     3326
# lga_desc                3326
# lga_ID                  3326
# Post\r\nCode               0
# Municipality               0
# ...

# %%
df.head()
# Out:
#   streetNumber streetName streetType        suburb  postcode state  \
# 0           11       Park         St    Abbotsford    3067.0   Vic
# 1           75     Halsey         Rd  Airport West    3042.0   Vic
# 2           18  Highridge         Cr  Airport West    3042.0   Vic
# 3           52   McIntosh         St  Airport West    3042.0   Vic
# 4           10   Delamare         Dr     Albanvale    3021.0   Vic
#
#     geoLocation        Lat    Unnamed: 8         Lng  ...  \
# 0  {'latitude': -37.809102  'longitude':  144.993725  ...
# 1  {'latitude': -37.719048  'longitude':  144.885001  ...
# 2  {'latitude': -37.727412  'longitude':  144.882599  ...
# 3  {'latitude': -37.720978  'longitude':  144.886008  ...
# 4  {'latitude': -37.742586  'longitude':  144.765858  ...
#
#                                               photos                LGA  \
# 0  https://bucket-api.domain.com.au/v1/bucket/ima...          Yarra (C)
# ...

# %%
df.drop_duplicates()
df
# Out:
#      streetNumber streetName streetType        suburb  postcode state  \
# 0              11       Park         St    Abbotsford    3067.0   Vic
# 1              75     Halsey         Rd  Airport West    3042.0   Vic
# 2              18  Highridge         Cr  Airport West    3042.0   Vic
# 3              52   McIntosh         St  Airport West    3042.0   Vic
# 4              10   Delamare         Dr     Albanvale    3021.0   Vic
# ...           ...        ...        ...           ...       ...   ...
# 3940          NaN        NaN        NaN           NaN       NaN   NaN
# 3941          NaN        NaN        NaN           NaN       NaN   NaN
# 3942          NaN        NaN        NaN           NaN       NaN   NaN
# 3943          NaN        NaN        NaN           NaN       NaN   NaN
# 3944          NaN        NaN        NaN           NaN       NaN   NaN
#
#        geoLocation        Lat    Unnamed: 8         Lng  ...  \
# 0     {'latitude': -37.809102  'longitude':  144.993725  ...
# ...

# %%
drop_all_na = df.dropna(how = 'all')
drop_all_na
# Out:
#      streetNumber streetName streetType        suburb  postcode state  \
# 0              11       Park         St    Abbotsford    3067.0   Vic
# 1              75     Halsey         Rd  Airport West    3042.0   Vic
# 2              18  Highridge         Cr  Airport West    3042.0   Vic
# 3              52   McIntosh         St  Airport West    3042.0   Vic
# 4              10   Delamare         Dr     Albanvale    3021.0   Vic
# ...           ...        ...        ...           ...       ...   ...
# 3940          NaN        NaN        NaN           NaN       NaN   NaN
# 3941          NaN        NaN        NaN           NaN       NaN   NaN
# 3942          NaN        NaN        NaN           NaN       NaN   NaN
# 3943          NaN        NaN        NaN           NaN       NaN   NaN
# 3944          NaN        NaN        NaN           NaN       NaN   NaN
#
#        geoLocation        Lat    Unnamed: 8         Lng  ...  \
# 0     {'latitude': -37.809102  'longitude':  144.993725  ...
# ...

# %%
drop_all_na = df.dropna(how = 'any')
drop_all_na
# Out:
#     streetNumber  streetName streetType          suburb  postcode state  \
# 3             52    McIntosh         St    Airport West    3042.0   Vic
# 7             15      McLean         St          Albion    3020.0   Vic
# 16           844     Malvern         Rd        Armadale    3143.0   Vic
# 17         23-25  St Georges         Rd        Armadale    3143.0   Vic
# 18            42   Roseberry         St      Ascot Vale    3032.0   Vic
# ..           ...         ...        ...             ...       ...   ...
# 609           19    Lambourn         Rd        Watsonia    3087.0   Vic
# 610           26    McKellar         St        Watsonia    3087.0   Vic
# 615          690      Barkly         St  West Footscray    3012.0   Vic
# 616           96     Roberts         St  West Footscray    3012.0   Vic
# 618        17-19   Grandview         Rd   Wheelers Hill    3150.0   Vic
#
#       geoLocation        Lat    Unnamed: 8         Lng  ...  \
# ...

# %%
import matplotlib.image as mpimg 
map_img = mpimg.imread('../smart dolphin.jpg') 
plt.figure(figsize=(15,10))
hmax=sns.barplot(data=df,x='bedrooms',y='price',palette='Set2',zorder = 2)
hmax.imshow(map_img,
          aspect = hmax.get_aspect(),
          extent = hmax.get_xlim() + hmax.get_ylim(),
          zorder = 1,alpha = 0.5)
plt.xlabel("Number of bedrooms", size=20)
plt.ylabel("price", size=20)
plt.title("Total Price of Houses in Melbourne by bedrooms", size=25)
plt.tight_layout()
plt.show()

# %%
map_img = mpimg.imread('../smart dolphin.jpg') 

plt.figure(figsize=(15,10))
hmax=sns.barplot(data=df,x='bathrooms',y='price',palette='Set2',zorder = 2)
hmax.imshow(map_img,
          aspect = hmax.get_aspect(),
          extent = hmax.get_xlim() + hmax.get_ylim(),
          zorder = 1,alpha = 0.5)
plt.xlabel("Number of bathrooms", size=20)
plt.ylabel("price", size=20)
plt.title("Total Price of Houses in Melbourne by bathrooms", size=25)
plt.tight_layout()
plt.show()

# %%
map_img = mpimg.imread('../smart dolphin.jpg') 

plt.figure(figsize=(15,10))
hmax=sns.barplot(data=df,x='carspaces',y='price',palette='Set2',zorder = 2)
hmax.imshow(map_img,
          aspect = hmax.get_aspect(),
          extent = hmax.get_xlim() + hmax.get_ylim(),
          zorder = 1,alpha = 0.5)
plt.xlabel("Number of Carport", size=20)
plt.ylabel("price", size=20)
plt.title("Total Price of Houses in Melbourne by Carport", size=25)
plt.tight_layout()
plt.show()

# %%
# plotting a heat map for all numeric variables
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),cmap = 'coolwarm',linewidth = 1,annot= True, annot_kws={"size": 9})
plt.title('HEAT MAP', fontsize=15)
plt.show()

# %%
df.hist(bins=50, figsize=(20,15))
plt.savefig("attribute_histogram_plots")
plt.show()

# %%
def plot_property_for_one(df, feature, value, ax):
    sns.scatterplot(x='Lng', y='Lat', data=df, alpha=0.5, color='white', ax=ax)
    ax.set_facecolor('0.6')
    ax.grid(False)
    color = sns.color_palette(n_colors=1)[0]
    sns.scatterplot(x='Lng', y='Lat', data=df.loc[df[feature] == value, :],
                    color=color, alpha=0.5, ax=ax)
    ax.set_title(value)
df
# Out:
#     streetNumber streetName streetType        suburb  postcode state  \
# 0             11       Park         St    Abbotsford    3067.0   Vic
# 1             75     Halsey         Rd  Airport West    3042.0   Vic
# 2             18  Highridge         Cr  Airport West    3042.0   Vic
# 3             52   McIntosh         St  Airport West    3042.0   Vic
# 4             10   Delamare         Dr     Albanvale    3021.0   Vic
# ..           ...        ...        ...           ...       ...   ...
# 623          202    Osborne         St  Williamstown    3016.0   Vic
# 624            9    Railway         Pl  Williamstown    3016.0   Vic
# 625           16  Chromatic         Rd       Wollert    3750.0   Vic
# 626           36   Varanasi         Dr       Wollert    3750.0   Vic
# 627           87   Hamilton         St    Yarraville    3013.0   Vic
#
#                                            geoLocation propertyType  bedrooms  \
# ...

# %%
# fig, axes = plt.subplots(3, 2, sharey=True, sharex=True)
df
highestSaleListingPrice = df.sort_values(by=["highestSaleListingPrice"],ascending=False)
# plot_property_for_one(highestSaleListingPrice[["suburb","highestSaleListingPrice"]].drop_duplicates(), 'toparea', axes[0][0])
# ax.set_facecolor('0.6')
# ax.grid(False)
color = sns.color_palette(n_colors=1)[0]
plt.xticks(rotation=45, ha='right')
dd=highestSaleListingPrice[["Lat","Lng","highestSaleListingPrice"]].drop_duplicates()
dd=dd.dropna()
print(dd)
sns.scatterplot(x=dd['Lat'], y=dd['Lng'], data=dd["highestSaleListingPrice"],
                    c=dd["highestSaleListingPrice"], alpha=0.5)
# ax.set_title(value)
# fig = plt.gcf()
# # fig.set_size_inches(16, 12)
# fig.suptitle('Phow()
highestSaleListingPrice[["suburb","highestSaleListingPrice"]].drop_duplicates()
# Out:
#            Lat         Lng  highestSaleListingPrice
# 301 -37.822211  145.032802               38000000.0
# 583 -37.843240  145.019024               33300000.0
# 244 -38.457454  144.972198               28429000.0
# 552 -37.542473  144.719238               26250000.0
# 139 -37.871263  145.019024               21000000.0
# ..         ...         ...                      ...
# 276 -37.704421  144.878623                 850000.0
# 365 -37.815207  144.963937                 789000.0
# 200 -38.115525  145.869060                 775000.0
# 356 -37.853515  145.035557                 669000.0
# 81  -38.176358  144.384984                 649000.0
#
# [170 rows x 3 columns]
#               suburb  highestSaleListingPrice
# 301         Hawthorn               38000000.0
# 583           Toorak               33300000.0
# 244         Flinders               28429000.0
# 552          Sunbury               26250000.0
# 139  Caulfield North               21000000.0
# ...
