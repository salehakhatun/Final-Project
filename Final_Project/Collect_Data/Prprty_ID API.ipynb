# %%
import pandas as pd
import json
from pprint import pprint 
# loading the dataframe with all the information that saved in previous task
source=pd.read_json('../listings.json')

pprint(source)

# %%
source['postcode'] = source['postcode'].astype("string")

# %%
house=source.iloc[[1]]
pprint(house['streetName'])
tt=house['streetNumber']+' '+house['streetName']+' '+house['streetType']+', '+house['suburb']+', '+'VIC'+' '+house['postcode']
tt

# %%
import requests

# Import API key
from api_keys import g_key
# loading the dataframe with all the information that saved in previous task


start=0
end=628
for i in range(start,end):

    house=source.iloc[[i]]
    
   # set up a parameters dictionary
    params = {
        "terms": house['streetNumber']+' '+house['streetName']+' '+house['streetType']+', '+house['suburb']+' '+'VIC'+' '+house['postcode'],
        "pagesize":1,
  
        "api_key": g_key
    }
 
    # base url
    base_url = "https://api.domain.com.au/v1/properties/_suggest"
 
    # run a request using our params dictionary
    response = requests.get(base_url, params=params).json()
   
    # extract results
    #results = response['results']
    
    try:
            #append to hotel data frame
      #  pprint(results)
      
      source['second_ID'].iloc[[i]]=response[0]['id']
    #   source_df['Domain_id'].iloc[i]=response[0]['ids'][0]['id']
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

# %%
source.to_json('../listings.json')

# %%
source
# Out:
#      streetNumber streetName streetType        suburb postcode state  \
# 1              11       Park         St    Abbotsford   3067.0   Vic
# 3              75     Halsey         Rd  Airport West   3042.0   Vic
# 4              18  Highridge         Cr  Airport West   3042.0   Vic
# 5              52   McIntosh         St  Airport West   3042.0   Vic
# 7              10   Delamare         Dr     Albanvale   3021.0   Vic
# ...           ...        ...        ...           ...      ...   ...
# 1043          202    Osborne         St  Williamstown   3016.0   Vic
# 1044            9    Railway         Pl  Williamstown   3016.0   Vic
# 1049           16  Chromatic         Rd       Wollert   3750.0   Vic
# 1051           36   Varanasi         Dr       Wollert   3750.0   Vic
# 1055           87   Hamilton         St    Yarraville   3013.0   Vic
#
#                                             geoLocation propertyType  \
# ...

# %%
pprint(response)
print(response[0]['id'])

# %%
from api_keys import g_key
print(g_key)
# Out:
# key_8e4d94a81aca99500d207f33b84633a6

# %%
from api_keys import g_key
import pandas as pd
import json

import requests
from pprint import pprint 
# loading the dataframe with all the information that saved in previous task
source=pd.read_csv('../listings.csv')

start=400
end=628
#628
for i in range(start,end):

    
    
   # set up a parameters dictionary
    params = {
          
        "api_key": g_key
    }
 
    # base url
    base_url = "https://api.domain.com.au/v1/properties/"+source['second_ID'].iloc[i]
    
    # run a request using our params dictionary
    response = requests.get(base_url, params=params).json()
   
    # extract results
    #results = response['results']
    
    try:
            #append to hotel data frame
      #  pprint(results)
      
      source['canonicalUrl'].iloc[i]=response['canonicalUrl']
      source['areaSize'].iloc[i]=response['areaSize']
      source['photos'].iloc[i]=response['photos'][0]['fullUrl']



    #   source_df['Domain_id'].iloc[i]=response[0]['ids'][0]['id']
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# ...

# %%
response
# Out:
# {'cadastreType': 'Polygon',
#  'onMarketTypes': [],
#  'status': 'OffMarket',
#  'address': '87 Hamilton Street, Yarraville VIC 3013',
#  'addressCoordinate': {'lat': -37.81176, 'lon': 144.88694},
#  'addressId': 2501313,
#  'areaSize': 291,
#  'bathrooms': 1,
#  'bedrooms': 3,
#  'carSpaces': 0,
#  'created': '2022-03-07T02:27:38.4Z',
#  'features': ['Heating', 'Study'],
#  'flatNumber': '',
#  'gnafIds': [{'monthNo': 11, 'yearNo': 2021, 'gnafPID': 'GAVIC419545772'}],
#  'id': 'PB-0275-AI',
#  'isResidential': True,
#  'photos': [{'imageType': 'Property',
#    'advertId': 2017642316,
#    'date': '2022-04-03T22:44:45.91Z',
#    'fullUrl': 'https://bucket-api.domain.com.au/v1/bucket/image/2017642316_1_1_220306_104542-w1600-h1067',
#    'rank': 1},
#   {'imageType': 'Property',
#    'advertId': 2017642316,
#    'date': '2022-04-03T22:44:45.91Z',
#    'fullUrl': 'https://bucket-api.domain.com.au/v1/bucket/image/2017642316_2_1_220306_104542-w1600-h1067',
#    'rank': 2},
# ...

# %%
source
# Out:
#      streetNumber streetName streetType        suburb  postcode state  \
# 1              11       Park         St    Abbotsford    3067.0   Vic
# 3              75     Halsey         Rd  Airport West    3042.0   Vic
# 4              18  Highridge         Cr  Airport West    3042.0   Vic
# 5              52   McIntosh         St  Airport West    3042.0   Vic
# 7              10   Delamare         Dr     Albanvale    3021.0   Vic
# ...           ...        ...        ...           ...       ...   ...
# 1043          202    Osborne         St  Williamstown    3016.0   Vic
# 1044            9    Railway         Pl  Williamstown    3016.0   Vic
# 1049           16  Chromatic         Rd       Wollert    3750.0   Vic
# 1051           36   Varanasi         Dr       Wollert    3750.0   Vic
# 1055           87   Hamilton         St    Yarraville    3013.0   Vic
#
#                                             geoLocation propertyType  \
# ...

# %%
source['second_ID'].iloc[0]
# Out:
# 'HN-2713-UF'

# %%
source.to_csv('../listings.csv',index=False)
