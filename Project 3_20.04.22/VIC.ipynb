# %%
#Import dependencies
import pandas as pd
import json
import requests
import numpy as np
from sqlalchemy import create_engine

# %%
#Read data in pandas 
data_file_1 = "VIC.csv"
VIC = pd.read_csv(data_file_1)
VIC.head()
# Out:
#          Suburb  Postcode        Lat         Lng  Domain_id  medianSoldPrice  \
# 0      Abbeyard      3737 -36.846683  146.696286        607              NaN
# 1    Abbotsford      3067 -37.802360  144.998362        627        1297000.0
# 2    Aberfeldie      3040 -37.749303  144.900631        647        1933000.0
# 3       Acheron      3714 -37.187299  145.624559        667              NaN
# 4  Adams Estate      3984 -38.311438  145.557993        677              NaN
#
#    numberSold  highestSoldPrice  lowestSoldPrice  medianSaleListingPrice  ...  \
# 0         NaN               NaN              NaN                     NaN  ...
# 1        23.0         2150000.0         630000.0               1273000.0  ...
# 2        18.0         4730000.0         735000.0               1750000.0  ...
# 3         NaN               NaN              NaN                     NaN  ...
# 4         NaN               NaN              NaN                     NaN  ...
#
# ...

# %%
data_file_2 = "listings.csv" 
listings = pd.read_csv(data_file_2)
listings.head()
# Out:
#   streetNumber streetName streetType        suburb  postcode state  \
# 0           11       Park         St    Abbotsford    3067.0   Vic
# 1           75     Halsey         Rd  Airport West    3042.0   Vic
# 2           18  Highridge         Cr  Airport West    3042.0   Vic
# 3           52   McIntosh         St  Airport West    3042.0   Vic
# 4           10   Delamare         Dr     Albanvale    3021.0   Vic
#
#                                          geoLocation propertyType  bedrooms  \
# 0  {'latitude': -37.8091018, 'longitude': 144.993...        House         4
# 1  {'latitude': -37.7190478, 'longitude': 144.885...        House         3
# 2  {'latitude': -37.7274118, 'longitude': 144.882...        House         3
# 3  {'latitude': -37.7209776, 'longitude': 144.886...    Townhouse         3
# 4  {'latitude': -37.742586, 'longitude': 144.7658...        House         4
#
#    bathrooms  ...                    agencyName  \
# 0        1.0  ...      Nelson Alexander Fitzroy
# ...

# %%
listings.count()
# Out:
# streetNumber            628
# streetName              628
# streetType              617
# suburb                  628
# postcode                619
# state                   619
# geoLocation             619
# propertyType            628
# bedrooms                628
# bathrooms               619
# carspaces               619
# result                  628
# agent                   628
# id                      628
# agencyId                628
# agencyName              619
# agencyProfilePageUrl    619
# propertyDetailsUrl      628
# price                   628
# unitNumber              179
# area                    628
# second_ID               628
# canonicalUrl            628
# areaSize                628
# photos                  628
# dtype: int64

# %%
data_file_3 = "LGA_ID.csv" 
LGA_ID = pd.read_csv(data_file_3)
LGA_ID.head()
# Out:
#               lga_desc  lga_ID
# 0  Greater Bendigo (C)       1
# 1        Melbourne (C)       2
# 2     Port Phillip (C)       3
# 3      Maribyrnong (C)       4
# 4      Hobsons Bay (C)       5

# %%
data_file_4 = "postcodeLGA.csv" 
postcodeLGA = pd.read_csv(data_file_4)
postcodeLGA.head()
# Out:
#    postcode                  LGA
# 0      2747  Greater Bendigo (C)
# 1      3000        Melbourne (C)
# 2      3000        Melbourne (C)
# 3      3002        Melbourne (C)
# 4      3002        Melbourne (C)

# %%
#Checked for data types
VIC.dtypes
# Out:
# Suburb                      object
# Postcode                     int64
# Lat                        float64
# Lng                        float64
# Domain_id                    int64
# medianSoldPrice            float64
# numberSold                 float64
# highestSoldPrice           float64
# lowestSoldPrice            float64
# medianSaleListingPrice     float64
# numberSaleListing          float64
# highestSaleListingPrice    float64
# lowestSaleListingPrice     float64
# auctionNumberAuctioned     float64
# auctionNumberSold          float64
# auctionNumberWithdrawn     float64
# daysOnMarket               float64
# medianRentListingPrice     float64
# numberRentListing          float64
# highestRentListingPrice    float64
# lowestRentListingPrice     float64
# dtype: object

# %%
listings.dtypes
# Out:
# streetNumber             object
# streetName               object
# streetType               object
# suburb                   object
# postcode                float64
# state                    object
# geoLocation              object
# propertyType             object
# bedrooms                  int64
# bathrooms               float64
# carspaces               float64
# result                   object
# agent                    object
# id                        int64
# agencyId                  int64
# agencyName               object
# agencyProfilePageUrl     object
# propertyDetailsUrl       object
# price                     int64
# unitNumber               object
# area                      int64
# second_ID                object
# canonicalUrl             object
# areaSize                  int64
# photos                   object
# dtype: object

# %%
LGA_ID.dtypes
# Out:
# lga_desc    object
# lga_ID       int64
# dtype: object

# %%
postcodeLGA.dtypes
# Out:
# postcode     int64
# LGA         object
# dtype: object

# %%
#checking for missing values
VIC.count()
# Out:
# Suburb                     2300
# Postcode                   2300
# Lat                        2300
# Lng                        2300
# Domain_id                  2300
# medianSoldPrice             513
# numberSold                 1082
# highestSoldPrice           1081
# lowestSoldPrice            1081
# medianSaleListingPrice      607
# numberSaleListing          1211
# highestSaleListingPrice    1200
# lowestSaleListingPrice     1199
# auctionNumberAuctioned      521
# auctionNumberSold           463
# auctionNumberWithdrawn        0
# daysOnMarket                432
# medianRentListingPrice      433
# numberRentListing           821
# highestRentListingPrice     806
# lowestRentListingPrice      821
# dtype: int64

# %%
VIC.drop_duplicates()
# Out:
#             Suburb  Postcode        Lat         Lng  Domain_id  \
# 0         Abbeyard      3737 -36.846683  146.696286        607
# 1       Abbotsford      3067 -37.802360  144.998362        627
# 2       Aberfeldie      3040 -37.749303  144.900631        647
# 3          Acheron      3714 -37.187299  145.624559        667
# 4     Adams Estate      3984 -38.311438  145.557993        677
# ...            ...       ...        ...         ...        ...
# 2295      Yulecart      3301 -37.725503  141.894551      46087
# 2296       Yundool      3727 -36.246700  145.958135      46097
# 2297        Yuroke      3063 -37.593075  144.840123      46107
# 2298       Yuulong      3237 -38.650571  143.455420      46117
# 2299       Zeerust      3634 -36.226680  145.425012      46127
#
#       medianSoldPrice  numberSold  highestSoldPrice  lowestSoldPrice  \
# 0                 NaN         NaN               NaN              NaN
# ...

# %%
VIC.count()
# Out:
# Suburb                     2300
# Postcode                   2300
# Lat                        2300
# Lng                        2300
# Domain_id                  2300
# medianSoldPrice             513
# numberSold                 1082
# highestSoldPrice           1081
# lowestSoldPrice            1081
# medianSaleListingPrice      607
# numberSaleListing          1211
# highestSaleListingPrice    1200
# lowestSaleListingPrice     1199
# auctionNumberAuctioned      521
# auctionNumberSold           463
# auctionNumberWithdrawn        0
# daysOnMarket                432
# medianRentListingPrice      433
# numberRentListing           821
# highestRentListingPrice     806
# lowestRentListingPrice      821
# dtype: int64

# %%
LGA_ID.count()
# Out:
# lga_desc    83
# lga_ID      83
# dtype: int64

# %%
LGA_ID = LGA_ID.drop_duplicates()
LGA_ID
# Out:
#                         lga_desc  lga_ID
# 0            Greater Bendigo (C)       1
# 1                  Melbourne (C)       2
# 2               Port Phillip (C)       3
# 3                Maribyrnong (C)       4
# 4                Hobsons Bay (C)       5
# ..                           ...     ...
# 78     VIC - unincorp Mt Baw Baw      79
# 79           South Gippsland (S)      80
# 80      Mornington Peninsula (S)      81
# 81  VIC - unincorp French Island      82
# 82                Bass Coast (S)      83
#
# [83 rows x 2 columns]

# %%
postcodeLGA.count()
# Out:
# postcode    6397
# LGA         6397
# dtype: int64

# %%
postcodeLGA = postcodeLGA.drop_duplicates(subset=['postcode'])
postcodeLGA
# Out:
#       postcode                  LGA
# 0         2747  Greater Bendigo (C)
# 1         3000        Melbourne (C)
# 3         3002        Melbourne (C)
# 11        3003        Melbourne (C)
# 16        3004     Port Phillip (C)
# ...        ...                  ...
# 6360      3992       Bass Coast (S)
# 6366      3995       Bass Coast (S)
# 6392      3996  South Gippsland (S)
# 6395      5291          Glenelg (S)
# 6396      8007        Melbourne (C)
#
# [710 rows x 2 columns]

# %%
postcodeLGA.to_csv('postcodeLGA_01.csv',index=False)

# %%
listings = listings.drop_duplicates()
listings
# Out:
#     streetNumber streetName streetType        suburb  postcode state  \
# 0             11       Park         St    Abbotsford    3067.0   Vic
# 1             75     Halsey         Rd  Airport West    3042.0   Vic
# 2             18  Highridge         Cr  Airport West    3042.0   Vic
# 3             52   McIntosh         St  Airport West    3042.0   Vic
# 4             10   Delamare         Dr     Albanvale    3021.0   Vic
# ..           ...        ...        ...           ...       ...   ...
# 623          202    Osborne         St  Williamstown    3016.0   Vic
# 624            9    Railway         Pl  Williamstown    3016.0   Vic
# 625           16  Chromatic         Rd       Wollert    3750.0   Vic
# 626           36   Varanasi         Dr       Wollert    3750.0   Vic
# 627           87   Hamilton         St    Yarraville    3013.0   Vic
#
#                                            geoLocation propertyType  bedrooms  \
# ...

# %%
listings.count()
# Out:
# streetNumber            628
# streetName              628
# streetType              617
# suburb                  628
# postcode                619
# state                   619
# geoLocation             619
# propertyType            628
# bedrooms                628
# bathrooms               619
# carspaces               619
# result                  628
# agent                   628
# id                      628
# agencyId                628
# agencyName              619
# agencyProfilePageUrl    619
# propertyDetailsUrl      628
# price                   628
# unitNumber              179
# area                    628
# second_ID               628
# canonicalUrl            628
# areaSize                628
# photos                  628
# dtype: int64

# %%
#Dropping Na values - how = all means drop only when all values are na - which is rare because the first five columns are populated 
drop_all_na = VIC.dropna(how = 'all')
drop_all_na
# Out:
#             Suburb  Postcode        Lat         Lng  Domain_id  \
# 0         Abbeyard      3737 -36.846683  146.696286        607
# 1       Abbotsford      3067 -37.802360  144.998362        627
# 2       Aberfeldie      3040 -37.749303  144.900631        647
# 3          Acheron      3714 -37.187299  145.624559        667
# 4     Adams Estate      3984 -38.311438  145.557993        677
# ...            ...       ...        ...         ...        ...
# 2295      Yulecart      3301 -37.725503  141.894551      46087
# 2296       Yundool      3727 -36.246700  145.958135      46097
# 2297        Yuroke      3063 -37.593075  144.840123      46107
# 2298       Yuulong      3237 -38.650571  143.455420      46117
# 2299       Zeerust      3634 -36.226680  145.425012      46127
#
#       medianSoldPrice  numberSold  highestSoldPrice  lowestSoldPrice  \
# 0                 NaN         NaN               NaN              NaN
# ...

# %%
#Dropping Na values - how = any means drop when even a single value is na - this doesn't return anything because there is a column called áuction number withdrawn'which is empty
drop_all_na = VIC.dropna(how = 'any')
drop_all_na
# Out:
# Empty DataFrame
# Columns: [Suburb, Postcode, Lat, Lng, Domain_id, medianSoldPrice, numberSold, highestSoldPrice, lowestSoldPrice, medianSaleListingPrice, numberSaleListing, highestSaleListingPrice, lowestSaleListingPrice, auctionNumberAuctioned, auctionNumberSold, auctionNumberWithdrawn, daysOnMarket, medianRentListingPrice, numberRentListing, highestRentListingPrice, lowestRentListingPrice]
# Index: []
#
# [0 rows x 21 columns]

# %%
# drop na's based on a subset
VIC_01 = VIC.dropna(subset=['highestSoldPrice', 'numberSaleListing', 'lowestSaleListingPrice'], how= 'all') 
VIC_01
# Out:
#             Suburb  Postcode        Lat         Lng  Domain_id  \
# 1       Abbotsford      3067 -37.802360  144.998362        627
# 2       Aberfeldie      3040 -37.749303  144.900631        647
# 4     Adams Estate      3984 -38.311438  145.557993        677
# 7     Aireys Inlet      3231 -38.451657  144.052113        737
# 8     Airport West      3042 -37.724520  144.875873        757
# ...            ...       ...        ...         ...        ...
# 2282           Yea      3717 -37.303014  145.402868      45917
# 2284         Yelta      3505 -34.189156  141.810022      45957
# 2285       Yeodene      3249 -38.368530  143.433809      45987
# 2290        Yinnar      3869 -38.363764  146.371233      46047
# 2291  Yinnar South      3869 -38.363764  146.371233      46057
#
#       medianSoldPrice  numberSold  highestSoldPrice  lowestSoldPrice  \
# 1           1297000.0        23.0         2150000.0         630000.0
# ...

# %%
#We have 1243 values left from 2300 values
VIC_01.to_csv('VIC_01.csv',index=False)
VIC_01
# Out:
#             Suburb  Postcode        Lat         Lng  Domain_id  \
# 1       Abbotsford      3067 -37.802360  144.998362        627
# 2       Aberfeldie      3040 -37.749303  144.900631        647
# 4     Adams Estate      3984 -38.311438  145.557993        677
# 7     Aireys Inlet      3231 -38.451657  144.052113        737
# 8     Airport West      3042 -37.724520  144.875873        757
# ...            ...       ...        ...         ...        ...
# 2282           Yea      3717 -37.303014  145.402868      45917
# 2284         Yelta      3505 -34.189156  141.810022      45957
# 2285       Yeodene      3249 -38.368530  143.433809      45987
# 2290        Yinnar      3869 -38.363764  146.371233      46047
# 2291  Yinnar South      3869 -38.363764  146.371233      46057
#
#       medianSoldPrice  numberSold  highestSoldPrice  lowestSoldPrice  \
# 1           1297000.0        23.0         2150000.0         630000.0
# ...

# %%
VIC.count()
# Out:
# Suburb                     1243
# Postcode                   1243
# Lat                        1243
# Lng                        1243
# Domain_id                  1243
# medianSoldPrice             513
# numberSold                 1082
# highestSoldPrice           1081
# lowestSoldPrice            1081
# medianSaleListingPrice      607
# numberSaleListing          1211
# highestSaleListingPrice    1200
# lowestSaleListingPrice     1199
# auctionNumberAuctioned      521
# auctionNumberSold           463
# auctionNumberWithdrawn        0
# daysOnMarket                432
# medianRentListingPrice      433
# numberRentListing           771
# highestRentListingPrice     756
# lowestRentListingPrice      771
# dtype: int64

# %%
listings_01 = listings.dropna(subset=['postcode'], how= 'all') 
listings_01 
listings_01.to_csv('listings_01.csv',index=False)

# %%
listings.count()
# Out:
# streetNumber            619
# streetName              619
# streetType              608
# suburb                  619
# postcode                619
# state                   619
# geoLocation             619
# propertyType            619
# bedrooms                619
# bathrooms               619
# carspaces               619
# result                  619
# agent                   619
# id                      619
# agencyId                619
# agencyName              619
# agencyProfilePageUrl    619
# propertyDetailsUrl      619
# price                   619
# unitNumber              176
# area                    619
# second_ID               619
# canonicalUrl            619
# areaSize                619
# photos                  619
# dtype: int64

# %%
#Created connection with local database SQL
rds_connection_string = "postgres:password@localhost:5432/Victoria_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# <ipython-input-141-d72bc75a6b62>:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['victoria', 'Victoria', 'listings']

# %%
#Use pandas to load csv converted dataframe to database
VIC_01.to_sql(name='Victoria', con=engine, if_exists='append', index=False)

# %%
#Confirm data has been added by querying the table
pd.read_sql_query('select * from Victoria', con=engine).head()
# Out:
#          suburb  postcode        lat         lng  domain_id  mediansoldprice  \
# 0    Abbotsford      3067 -37.802360  144.998362        627        1297000.0
# 1    Aberfeldie      3040 -37.749303  144.900631        647        1933000.0
# 2  Adams Estate      3984 -38.311438  145.557993        677              NaN
# 3  Aireys Inlet      3231 -38.451657  144.052113        737              NaN
# 4  Airport West      3042 -37.724520  144.875873        757         988000.0
#
#    numbersold  highestsoldprice  lowestsoldprice  mediansalelistingprice  ...  \
# 0        23.0         2150000.0         630000.0               1273000.0  ...
# 1        18.0         4730000.0         735000.0               1750000.0  ...
# 2         NaN               NaN              NaN                     NaN  ...
# 3         5.0         2350000.0         124000.0                     NaN  ...
# 4        28.0         1420000.0         600000.0                880000.0  ...
#
# ...

# %%
listings_01.to_sql(name='Listings', con=engine, if_exists='append', index=False)

# %%
#Confirm data has been added by querying the table
pd.read_sql_query('select * from Listings', con=engine).head()
# Out:
#   streetnumber streetname streettype        suburb  postcode state  \
# 0           11       Park         St    Abbotsford    3067.0   Vic
# 1           75     Halsey         Rd  Airport West    3042.0   Vic
# 2           18  Highridge         Cr  Airport West    3042.0   Vic
# 3           52   McIntosh         St  Airport West    3042.0   Vic
# 4           10   Delamare         Dr     Albanvale    3021.0   Vic
#
#                                          geolocation propertytype  bedrooms  \
# 0  {'latitude': -37.8091018, 'longitude': 144.993...        House         4
# 1  {'latitude': -37.7190478, 'longitude': 144.885...        House         3
# 2  {'latitude': -37.7274118, 'longitude': 144.882...        House         3
# 3  {'latitude': -37.7209776, 'longitude': 144.886...    Townhouse         3
# 4  {'latitude': -37.742586, 'longitude': 144.7658...        House         4
#
#    bathrooms  ...                    agencyname  \
# 0        1.0  ...      Nelson Alexander Fitzroy
# ...

# %%
LGA_ID.to_sql(name='LGA_ID', con=engine, if_exists='append', index=False)

# %%
#Confirm data has been added by querying the table
pd.read_sql_query('select * from LGA_ID', con=engine).head()
# Out:
#               lga_desc  lga_id
# 0  Greater Bendigo (C)       1
# 1        Melbourne (C)       2
# 2     Port Phillip (C)       3
# 3      Maribyrnong (C)       4
# 4      Hobsons Bay (C)       5

# %%
postcodeLGA.to_sql(name='postcodeLGA', con=engine, if_exists='append', index=False)

# %%
#Confirm data has been added by querying the table
pd.read_sql_query('select * from postcodeLGA', con=engine).head()
# Out:
#    postcode                  lga
# 0      2747  Greater Bendigo (C)
# 1      3000        Melbourne (C)
# 2      3002        Melbourne (C)
# 3      3003        Melbourne (C)
# 4      3004     Port Phillip (C)
